# %%
import pandas as pd

# %%
data = pd.read_csv('final.csv')

# %%
print(data['3'].sum())
# Out:
# 222.0

# %%
data.head()
# Out:
#    Unnamed: 0                 0  1  \
# 0           0  Amazon Conscript  1
# 1           1        Battlebard  1
# 2           2   Street Conjuror  1
# 3           3   Spellsight Seer  1
# 4           4    Switch Duelist  1
#
#                                                    2    3          4  5     6  \
# 0    Roar: Remove confused from a friendly creature.  6.0     nature  0  core
# 1          Roar: Give a friendly Viking +2 strength.  2.0    neutral  0  core
# 2                                    Spell boost +1.  2.0      magic  0  core
# 3                                   Roar: Foresee 1.  1.0      magic  0  core
# 4  Hidden for 1 turn. At the end of each player's...  3.0  deception  0  core
#
#         7  8  9      10        11        12
# 0  amazon  2  2  common  0.103998  0.000081
# 1  viking  2  1    epic  0.978900  0.000900
# 2  mystic  1  3    rare  0.490000  0.000455
# 3  mystic  2  2  common  0.100000  0.000081
# 4   guild  3  1    rare  0.468990  0.000409

# %%
data.columns = ['index', 'Name','Mana_Cost', 'Description', 'Quantity','GOD', 'Price', 'Set','Tribe', 'Attack','Health','Rarity', 'Price_GODS', 'Price_ETH']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        69 non-null     int64
#  1   Name         69 non-null     object
#  2   Mana_Cost    69 non-null     int64
#  3   Description  69 non-null     object
#  4   Quantity     68 non-null     float64
#  5   GOD          69 non-null     object
#  6   Price        69 non-null     int64
#  7   Set          69 non-null     object
#  8   Tribe        69 non-null     object
#  9   Attack       69 non-null     int64
#  10  Health       69 non-null     int64
#  11  Rarity       69 non-null     object
#  12  Price_GODS   69 non-null     float64
#  13  Price_ETH    69 non-null     float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 7.7+ KB

# %%
data.head()
# Out:
#    index              Name  Mana_Cost  \
# 0      0  Amazon Conscript          1
# 1      1        Battlebard          1
# 2      2   Street Conjuror          1
# 3      3   Spellsight Seer          1
# 4      4    Switch Duelist          1
#
#                                          Description  Quantity        GOD  \
# 0    Roar: Remove confused from a friendly creature.       6.0     nature
# 1          Roar: Give a friendly Viking +2 strength.       2.0    neutral
# 2                                    Spell boost +1.       2.0      magic
# 3                                   Roar: Foresee 1.       1.0      magic
# 4  Hidden for 1 turn. At the end of each player's...       3.0  deception
#
#    Price   Set   Tribe  Attack  Health  Rarity  Price_GODS  Price_ETH
# 0      0  core  amazon       2       2  common    0.103998   0.000081
# 1      0  core  viking       2       1    epic    0.978900   0.000900
# 2      0  core  mystic       1       3    rare    0.490000   0.000455
# 3      0  core  mystic       2       2  common    0.100000   0.000081
# 4      0  core   guild       3       1    rare    0.468990   0.000409

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\users\seann\pycharmprojects\pythonproject\venv\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File c:\users\seann\pycharmprojects\pythonproject\venv\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\users\seann\pycharmprojects\pythonproject\venv\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'newPrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <module>
# ----> 1 type(data['newPrice'])
#       2 data['newPrice']
#
# File c:\users\seann\pycharmprojects\pythonproject\venv\lib\site-packages\pandas\core\frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File c:\users\seann\pycharmprojects\pythonproject\venv\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: 'newPrice'

# %%
data['Price'].loc[0][1]
# Out:
# '[0.12499, 9.7e-05]'

# %%
data['Price'].info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 data['Price'].info()
#
# NameError: name 'data' is not defined

# %%
import requests
ETH_USD = 0.00000
GODS_USD = 0.00000
def updateRefPrices():
    url = 'https://api.coingecko.com/api/v3/simple/price?ids=ethereum&vs_currencies=usd'
    response = requests.get(url)
    data = response.json()
    print(data)
    ETH_USD = data['ethereum']['usd']
    headers ={ "X-RapidAPI-Key": "f9e79c11-b10e-4126-886e-64ae0574a74e", "Content-Type": "application/x-www-form-urlencoded"
               }
    url = 'https://pro-api.coinmarketcap.com/v1/tools/price-conversion'
    response = requests.get(url)
    data = response.json()

ETH_USD = 3193.44
GODS_USD = 3.17
    #ETH - GODS
def priceDifference(eth, gods):
    usd_dif = eth * ETH_USD - GODS_USD * gods
    return usd_dif

# %%
print(ETH_USD)

data['dif'] = data['Price_ETH'].astype(float) * ETH_USD - data['Price_GODS'].astype(float) * GODS_USD
# Out:
# 3193.44

# %%
data[data['dif']>0].sort_values('dif', ascending=False)
# Out:
#     index               Name  Mana_Cost  \
# 24     24        Bright Mage          3
# 51     51   Minotaur Phalanx          6
# 57     57   Minotaur Phalanx          6
# 52     52        Green Giant          6
# 58     58        Green Giant          6
# 33     33    Nefarious Briar          4
# 21     21  Jinxblade Duelist          3
#
#                                           Description  Quantity        GOD  \
# 24      Ward.\nRoar: Heal a friendly character for 2.       1.0      light
# 51                                         Frontline.       4.0    neutral
# 57                                         Frontline.       4.0    neutral
# 52                                Confused. Overkill.       4.0     nature
# 58                                Confused. Overkill.       4.0     nature
# 33  Regen 1.\nRoar: Remove 4 durability from your ...       4.0     nature
# 21  At the end of each turn, give this creature +1...       4.0  deception
#
#     Price   Set   Tribe  Attack  Health  Rarity  Price_GODS  Price_ETH  \
# 24      0  core  mystic       3       3  common       0.105   0.000158
# 51      0  core    wild       4       8  common       0.118   0.000126
# 57      0  core    wild       4       8  common       0.118   0.000126
# 52      0  core    wild       7       8  common       0.120   0.000124
# 58      0  core    wild       7       8  common       0.120   0.000124
# 33      0  core    wild       3       4  common       0.128   0.000129
# 21      0  core   guild       4       2  common       0.115   0.000116
#
#          dif
# 24  0.171714
# 51  0.028313
# 57  0.028313
# 52  0.015587
# 58  0.015587
# 33  0.006194
# 21  0.005889

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        69 non-null     int64
#  1   Name         69 non-null     object
#  2   Mana_Cost    69 non-null     int64
#  3   Description  69 non-null     object
#  4   Quantity     68 non-null     float64
#  5   GOD          69 non-null     object
#  6   Price        69 non-null     int64
#  7   Set          69 non-null     object
#  8   Tribe        69 non-null     object
#  9   Attack       69 non-null     int64
#  10  Health       69 non-null     int64
#  11  Rarity       69 non-null     object
#  12  Price_GODS   69 non-null     float64
#  13  Price_ETH    69 non-null     float64
#  14  dif          69 non-null     float64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 8.2+ KB

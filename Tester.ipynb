# %%
import pandas as pd

# %%
data = pd.read_csv('final.csv')

# %%
print(data['3'].sum())
# Out:
# 222.0

# %%
data.head()
# Out:
#    Unnamed: 0                 0  1  \
# 0           0  Amazon Conscript  1
# 1           1        Battlebard  1
# 2           2   Street Conjuror  1
# 3           3   Spellsight Seer  1
# 4           4    Switch Duelist  1
#
#                                                    2    3          4  5     6  \
# 0    Roar: Remove confused from a friendly creature.  6.0     nature  0  core
# 1          Roar: Give a friendly Viking +2 strength.  2.0    neutral  0  core
# 2                                    Spell boost +1.  2.0      magic  0  core
# 3                                   Roar: Foresee 1.  1.0      magic  0  core
# 4  Hidden for 1 turn. At the end of each player's...  3.0  deception  0  core
#
#         7  8  9      10                  11
# 0  amazon  2  2  common  [0.12499, 9.7e-05]
# 1  viking  2  1    epic     [1.0, 0.000802]
# 2  mystic  1  3    rare     [0.589, 0.0005]
# 3  mystic  2  2  common     [0.11, 8.1e-05]
# 4   guild  3  1    rare  [0.6045, 0.000455]

# %%
data.columns = ['index', 'Name','Mana_Cost', 'Description', 'Quantity','GOD', 'Price', 'Set','Tribe', 'Attack','Health','Rarity', 'Price']

# %%
data['Price']
# Out:
#    Price               Price
# 0      0  [0.12499, 9.7e-05]
# 1      0     [1.0, 0.000802]
# 2      0     [0.589, 0.0005]
# 3      0     [0.11, 8.1e-05]
# 4      0  [0.6045, 0.000455]
# ..   ...                 ...
# 64     0    [0.73, 0.000625]
# 65     0     [0.88, 0.00055]
# 66     0    [0.103, 7.2e-05]
# 67     0              [0, 0]
# 68     0   [0.1089, 7.9e-05]
#
# [69 rows x 2 columns]

# %%
data['newPrice'], data['what']= data['Price'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26852/1177807320.py in <module>
# ----> 1 data['newPrice'], data['what']= data['Price'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
data['newPrice']
# Out:
# 0     Price
# 1     Price
# 2     Price
# 3     Price
# 4     Price
#       ...
# 64    Price
# 65    Price
# 66    Price
# 67    Price
# 68    Price
# Name: newPrice, Length: 69, dtype: object

# %%
data['what'].head()
# Out:
# 0    Price
# 1    Price
# 2    Price
# 3    Price
# 4    Price
# Name: what, dtype: object

# %%
type(data['newPrice'])
data['newPrice']

# %%
data['Price'].loc[0][1]

# %%
data['Price'].info()
